# %%
import scipy as sp 
import pandas as pd
from tqdm import tqdm
from konlpy.tag import Hannanum
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
dic = {'tv': [62],
 '가방': [24, 26],
 '가위': [76],
 '간식': [52, 53, 54, 55],
 '강아지': [16],
 '개': [16],
 '거실': [57],
 '견종': [16],
 '경마': [17],
 '고속열차': [6],
 '고양이': [15],
 '곰': [21],
 '곰돌이': [21],
 '곰인형': [77],
 '공': [32],
 '공항': [4],
 '과일': [46, 47, 49],
 '교통': [9],
 '그릇': [45],
 '글라스': [40],
 '기린': [23],
 '기차': [6],
 '까치': [14],
 '꽃': [58, 75],
 '꽃병': [75],
 '나이프': [43],
 '냉장고': [72],
 '넥타이': [27],
 '노트북': [63],
 '당근': [51],
 '대중교통': [5],
 '도넛': [54],
 '도로': [9],
 '도서관': [73],
 '독서': [73],
 '동물': [15, 16, 17, 18, 19, 20, 21, 22, 23],
 '드라이기': [78],
 '디저트': [54, 55],
 '라켓': [38],
 '랩탑': [63],
 '리모컨': [65],
 '리모콘': [65],
 '마우스': [64],
 '말': [17],
 '멍멍': [16],
 '멍멍이': [16],
 '목장': [19],
 '문구': [76],
 '물병': [39],
 '물컵': [41],
 '미니백': [26],
 '바나나': [46],
 '밥그릇': [45],
 '방망이': [34],
 '배': [8],
 '배낭': [24],
 '배달': [3],
 '배트': [34],
 '백': [26],
 '백팩': [24],
 '버스': [5],
 '벤치': [13],
 '변기': [61],
 '변기통': [61],
 '병': [39],
 '병류': [39],
 '보드': [31, 36],
 '보트': [8],
 '볼': [32, 45],
 '부엌': [71, 72],
 '북극곰': [21],
 '브로콜리': [50],
 '비둘기': [14],
 '비행기': [4],
 '빵': [48, 54, 55],
 '사과': [47],
 '사람': [0],
 '사람들': [0],
 '새': [14],
 '샌드위치': [48],
 '생일': [55],
 '서프': [37],
 '서프보드': [37],
 '서핑': [37],
 '세면대': [61],
 '소': [19],
 '소떼': [19],
 '소파': [57],
 '소화기': [10],
 '소화전': [10],
 '숄더백': [26],
 '수저': [44],
 '숟가락': [44],
 '술병': [39],
 '술잔': [40],
 '스노우보드': [31],
 '스마트폰': [67],
 '스케이트': [36],
 '스케이트보드': [36],
 '스키': [30],
 '스키보드': [30],
 '스키장': [30, 31],
 '스포츠공': [32],
 '스푼': [44],
 '승마': [17],
 '승마장': [17],
 '승용차': [2],
 '시계': [74],
 '식기류': [42],
 '식사': [40, 41, 42, 43, 44, 45, 48, 52, 53, 60],
 '식탁': [60],
 '신호등': [9],
 '싱크': [71],
 '싱크대': [71],
 '안방': [59],
 '야구': [34, 34, 35],
 '야구방망이': [34],
 '야구장갑': [35],
 '야옹': [15],
 '야옹이': [15],
 '야채': [50, 51],
 '양': [18],
 '양떼': [18],
 '양치': [79],
 '얼룩말': [22],
 '여행': [28],
 '여행가방': [28],
 '연': [33],
 '연날리기': [33],
 '열차': [6],
 '오렌지': [49],
 '오븐': [69],
 '오토바이': [3],
 '와인잔': [40],
 '요리': [50, 51, 68, 69],
 '요트': [8],
 '우산': [25],
 '운동': [32, 34, 35, 36, 37],
 '운전': [2],
 '원반': [29],
 '원반던지기': [29],
 '유리컵': [41],
 '음메': [19],
 '음식': [45, 48, 52, 53, 54, 55],
 '의자': [13, 56],
 '인간': [0],
 '인형': [77],
 '일': [63],
 '자동차': [2],
 '자전거': [1],
 '작업': [63],
 '잠': [59],
 '장갑': [35],
 '전동차': [3],
 '전자레인지': [68],
 '전화' : [67],
 '접시': [45],
 '정지': [11],
 '정지 신호': [11],
 '조류': [14],
 '주스병': [39],
 '주차': [12],
 '주차 미터기': [12],
 '주차장': [12],
 '차': [2],
 '차량': [2],
 '참새': [14],
 '채소': [50, 51],
 '책': [73],
 '책방': [73],
 '책장': [73],
 '출국': [28],
 '치약': [79],
 '침대': [59],
 '침실': [59],
 '칫솔': [79],
 '칼': [43],
 '캐리어': [28],
 '컴퓨터': [63],
 '컵': [41],
 '케이크': [55],
 '코끼리': [20],
 '키보드': [66],
 '타이': [27],
 '타자': [34],
 '테니스': [38],
 '테니스 라켓': [38],
 '테디베어': [77],
 '텔레비전': [62],
 '토스터': [70],
 '토스트': [48, 70],
 '토스트기': [70],
 '투수': [35],
 '트럭': [7],
 '티비': [62],
 '포수': [35],
 '포크': [42],
 '폰': [67],
 '프리스비': [29],
 '프리즈비': [29],
 '피자': [53],
 '핫도그': [52],
 '항공': [4],
 '해양스포츠': [37],
 '핸드백': [26],
 '핸드폰': [67],
 '화병': [75],
 '화분': [58],
 '화장실': [61, 79],
 '화초': [58],
 '휴대폰': [67]}

# %% [markdown]
# # Tf-IDF & 유클리디안 유사도

# %%
od_raw = pd.read_csv('./산꾼도시여자들_i.csv', header=None, index_col=False, names=['drop', 'start', 'end', 'object_nums', 4, 5, 6, 7])
od_raw.drop(['drop'], axis=1, inplace=True)
od_raw

# 3초 단위로 자름
n = 1
detector = []
for time in tqdm(range(0, int(od_raw.iloc[-1,1] + n), n)):
# for time in tqdm(range(0, 100, 3)):
    tmp = []
    for i in range(len(od_raw)) :
        if (time < od_raw.iloc[i,0] <= time+3) or (time < od_raw.iloc[i,1] <= time+3):
            dect_num = int(od_raw.iloc[i,2].split('_')[0])
            for key, val in dic.items():
                # print(key, val, dect_num)
                if val.count(dect_num) != 0:
                    # print(f'{time} ~ {time+3} : {key}')
                    tmp.append(key)
    if tmp == []:
        continue
    else:
        detector.append({
        "start" : time,
        "end" : time+n,
        "detect" : ' '.join(list(set(tmp)))
        })

df_detector = pd.DataFrame(detector)

# detector vectorize
contents_for_vectorize = []
for idx, row in df_detector.iterrows():
    contents_for_vectorize.append(row[2])

stop_words = ['소리', '장면']
vectorizer = TfidfVectorizer(min_df=1, decode_error='ignore', stop_words=stop_words)
X = vectorizer.fit_transform(contents_for_vectorize)


hannanum = Hannanum()
input = '컵 그릇 티비 물 음식 가방 물컵'
new_post_tokens = hannanum.nouns(input)
new_post_for_vectorize = [' '.join(new_post_tokens)]
print(f'input query의 토큰화 ==> {new_post_for_vectorize}')
new_post_vec = vectorizer.transform(new_post_for_vectorize)

def dist_norm(v1, v2):
    v1_normalized = v1 / sp.linalg.norm(v1.toarray())
    v2_normalized = v2 / sp.linalg.norm(v2.toarray())

    delta = v1_normalized - v2_normalized

    return sp.linalg.norm(delta.toarray())

dist = [dist_norm(each, new_post_vec) for each in X]


print('-'*50)
print(f'Best post is {dist.index(min(dist))}, dist = {min(dist)}')
print(f'input query ==> "{input}"')
print(f'Test post is ==> {new_post_tokens}')
print()
print(f"""Best dist post is ==> {df_detector['start'][dist.index(min(dist))]}초 ~ {df_detector['end'][dist.index(min(dist))]}초
                                : {contents_for_vectorize[dist.index(min(dist))]}""");
# Out:
# 100%|██████████| 917/917 [00:52<00:00, 17.36it/s]
# input query의 토큰화 ==> ['컵 그릇 티비 음식 가방 물컵']
# --------------------------------------------------
# Best post is 0, dist = 0.9387052015430349
# input query ==> "컵 그릇 티비 물 음식 가방 물컵"
# Test post is ==> ['컵', '그릇', '티비', '음식', '가방', '물컵']
#
# Best dist post is ==> 0초 ~ 1초
#                                 : 유리컵 그릇 인간 컵 식사 병 주스병 사람 음식 백팩 밥그릇 술병 접시 물컵 가방 텔레비전 볼 병류 tv 배낭 사람들 티비 물병

# %%
stop_words = ['소리', '장면']
vectorizer = TfidfVectorizer(min_df=1, decode_error='ignore', stop_words=stop_words)
X = vectorizer.fit_transform(contents_for_vectorize)


hannanum = Hannanum()
input = '식탁에서 마이크로 노래부르는 장면'
new_post_tokens = hannanum.nouns(input)
new_post_for_vectorize = [' '.join(new_post_tokens)]
print(f'input query의 토큰화 ==> {new_post_for_vectorize}')
new_post_vec = vectorizer.transform(new_post_for_vectorize)

def dist_norm(v1, v2):
    v1_normalized = v1 / sp.linalg.norm(v1.toarray())
    v2_normalized = v2 / sp.linalg.norm(v2.toarray())

    delta = v1_normalized - v2_normalized

    return sp.linalg.norm(delta.toarray())

dist = [dist_norm(each, new_post_vec) for each in X]


print('-'*50)
print(f'Best post is {dist.index(min(dist))}, dist = {min(dist)}')
print(f'input query ==> "{input}"')
print(f'Test post is ==> {new_post_tokens}')
print()
print(f"""Best dist post is ==> {df_detector['start'][dist.index(min(dist))]}초 ~ {df_detector['end'][dist.index(min(dist))]}초
                                : {contents_for_vectorize[dist.index(min(dist))]}""");
# Out:
# input query의 토큰화 ==> ['식탁 마이크 장면']
# --------------------------------------------------
# Best post is 262, dist = 0.8269556296017903
# input query ==> "식탁에서 마이크로 노래부르는 장면"
# Test post is ==> ['식탁', '마이크', '장면']
#
# Best dist post is ==> 271초 ~ 272초
#                                 : 인간 식사 사람들 식탁 사람

# %% [markdown]
# # TF-IDF & COS 유사도

# %%
stop_words = ['소리', '장면']
vectorizer = TfidfVectorizer(min_df=1, decode_error='ignore', stop_words=stop_words)
X = vectorizer.fit_transform(contents_for_vectorize)


hannanum = Hannanum()
input = '식탁에서 마이크로 노래부르는 장면'
new_post_tokens = hannanum.nouns(input)
new_post_for_vectorize = [' '.join(new_post_tokens)]
print(f'input query의 토큰화 ==> {new_post_for_vectorize}')
new_post_vec = vectorizer.transform(new_post_for_vectorize)

 
def norm_cos_sim(v1, v2):
    v1_normalized = v1 / sp.linalg.norm(v1.toarray())
    v2_normalized = v2 / sp.linalg.norm(v2.toarray())
    delta = cosine_similarity(v1_normalized, v2_normalized)
    return sp.linalg.norm(delta) 
    # return sp.linalg.norm(delta.toarray())

dist = [norm_cos_sim(each, new_post_vec) for each in X]


print('-'*50)
print(f'Best post is {dist.index(max(dist))}, dist = {max(dist)}')
print(f'input query ==> "{input}"')
print(f'Test post is ==> {new_post_tokens}')
print()
print(f"""Best dist post is ==> {df_detector['start'][dist.index(max(dist))]}초 ~ {df_detector['end'][dist.index(max(dist))]}초
                                : {contents_for_vectorize[dist.index(max(dist))]}""");
# Out:
# input query의 토큰화 ==> ['식탁 마이크 장면']
# --------------------------------------------------
# Best post is 262, dist = 0.6580721933349534
# input query ==> "식탁에서 마이크로 노래부르는 장면"
# Test post is ==> ['식탁', '마이크', '장면']
#
# Best dist post is ==> 271초 ~ 272초
#                                 : 인간 식사 사람들 식탁 사람

# %% [markdown]
# ---

# %% [markdown]
# # 쿼리문 조작

# %%
# 1안 (기존) : 그냥 토큰화

hannanum = Hannanum()
input = '식탁에서 마이크로 노래부르는 장면'
new_post_tokens = hannanum.nouns(input)
new_post_for_vectorize = [' '.join(new_post_tokens)]
print(f'input query의 토큰화 ==> {new_post_for_vectorize}')
new_post_vec = vectorizer.transform(new_post_for_vectorize)

# %%
# 2안 : dic에서 가져오기

hannanum = Hannanum()
input = '식탁에서 마이크로 노래부르는 장면'
tokens = hannanum.nouns(input)
new_post_tokens = []

for token in tokens:
    tmp = []
    for key, val in dic.items():
        try:
            if token == key:
                dect_num = val

                for n in dect_num :
                    for key2, val2 in dic.items():
                        if val2.count(n) != 0:
                            tmp.append(key2)
        except:
            pass

    if tmp == []:
        continue
    else:
        for i in range(len(tmp)):
            new_post_tokens.append(tmp[i])
new_post_tokens
# Out:
# ['식사', '식탁']

# %%
# 3안 : dic에서 단일 key 값은 그것만 가져오기

hannanum = Hannanum()
input = '식탁에서 마이크로 노래부르는 장면'
tokens = hannanum.nouns(input)
new_post_tokens = []

for token in tokens:
    tmp = []
    for key, val in dic.items():
        try:
            if token == key and len(val) == 1:
                tmp.append(key)

            elif token == key and len(val) != 1:
                dect_num = val
                for n in dect_num :
                    for key2, val2 in dic.items():
                        if val2.count(n) != 0:
                            tmp.append(key2)
        except:
            pass

    if tmp == []:
        continue
    else:
        for i in range(len(tmp)):
            new_post_tokens.append(tmp[i])
new_post_tokens
# Out:
# ['식탁']

# %% [markdown]
# ---

# %%
hannanum = Hannanum()
input = '식탁에서 마이크로 노래부르는 장면'
tokens = hannanum.nouns(input)
new_post_tokens = []

for token in tokens:
    tmp = []
    for key, val in dic.items():
        try:
            if token == key:
                dect_num = val

                for n in dect_num :
                    for key2, val2 in dic.items():
                        if val2.count(n) != 0:
                            tmp.append(key2)
        except:
            pass

    if tmp == []:
        continue
    else:
        for i in range(len(tmp)):
            new_post_tokens.append(tmp[i])

new_post_tokens = list(set(new_post_tokens))
new_post_for_vectorize = [' '.join(new_post_tokens)]
print(f'input query의 토큰화 ==> {new_post_for_vectorize}')
new_post_vec = vectorizer.transform(new_post_for_vectorize)


def norm_cos_sim(v1, v2):
    v1_normalized = v1 / sp.linalg.norm(v1.toarray())
    v2_normalized = v2 / sp.linalg.norm(v2.toarray())
    delta = cosine_similarity(v1_normalized, v2_normalized)
    return sp.linalg.norm(delta) 
    # return sp.linalg.norm(delta.toarray())

dist = [norm_cos_sim(each, new_post_vec) for each in X]


print('-'*50)
print(f'Best post is {dist.index(max(dist))}, dist = {max(dist)}')
print(f'input query ==> "{input}"')
print(f'Test post is ==> {new_post_tokens}')
print()
print(f"""Best dist post is ==> {df_detector['start'][dist.index(max(dist))]}초 ~ {df_detector['end'][dist.index(max(dist))]}초
                                : {contents_for_vectorize[dist.index(max(dist))]}""");

# %%
n = 1
detector = []
# for time in tqdm(range(0, int(od_raw.iloc[-1,1] + n), n)):
for time in tqdm(range(0, 10, 1)):
    tmp = []
    for i in range(len(od_raw)) :
        if (time < od_raw.iloc[i,0] <= time+1) or (time < od_raw.iloc[i,1] <= time+1):
            dect_num = int(od_raw.iloc[i,2].split('_')[0])
            dic_tmp = []
            for key, val in dic.items():
                # print(key, val, dect_num)
                if val.count(dect_num) != 0:    # od가 있고
                    if len(val) == 1:   # od가 1개짜리면 바로 append
                        tmp.append(key)
                        break
                    elif len(val) > 1 : # od가 여러개인 추상화면 일단 
                        dic_tmp.append(key)
            if tmp == []:
                tmp = dic_tmp


    if tmp == []:
        continue
    else:
        detector.append({
        "start" : time,
        "end" : time+1,
        "detect" : ' '.join(list(set(tmp)))
        })

df_detector = pd.DataFrame(detector)

df_detector.detect[0]
# Out:
# 100%|██████████| 10/10 [00:00<00:00, 15.51it/s]
# '사람 물컵 그릇 물병'

# %% [markdown]
# 0초~1초 : 41(물컵), 0(사람), 45(그릇), 45(그릇), 0(사람), 0(사람), 물병(39), 병(39), 병류(39), 술병(39), 쥬스병(39)
#
# - 1개의 라벨인것도 너무 많아서 불가능..

# %%
hannanum = Hannanum()
input = '식탁에서 마이크로 노래부르는 장면'
hannanum.nouns(input)
# Out:
# ['식탁', '마이크', '장면']

# %%
# 딱 맞는건, 그 key만 가져오기

hannanum = Hannanum()
input = '식탁에서 마이크로 노래부르는 장면'
tokens = hannanum.nouns(input)
new_post_tokens = []

for token in tokens:
    tmp = []
    for key, val in dic.items():
        try:
            if token == key and len(val) == 1:
                tmp.append(key)

            elif token == key and len(val) != 1:
                dect_num = val
                for n in dect_num :
                    for key2, val2 in dic.items():
                        if val2.count(n) != 0:
                            tmp.append(key2)
        except:
            pass

    if tmp == []:
        continue
    else:
        for i in range(len(tmp)):
            new_post_tokens.append(tmp[i])
new_post_tokens
# Out:
# ['식탁']

# %% [markdown]
# # Test하는 법

# %%
df_detector.head()
# Out:
#    start  end                                             detect
# 0      0    1  유리컵 그릇 인간 컵 식사 병 주스병 사람 음식 백팩 밥그릇 술병 접시 물컵 가방 ...
# 1      1    2  유리컵 그릇 인간 컵 식사 병 주스병 사람 음식 빵 백팩 밥그릇 술병 접시 물컵 가...
# 2      2    3  그릇 인간 식사 병 주스병 사람 음식 빵 백팩 밥그릇 술병 접시 가방 텔레비전 식탁...
# 3      3    4  유리컵 그릇 인간 컵 식사 병 주스병 사람 음식 빵 밥그릇 술병 접시 물컵 텔레비전...
# 4      4    5  유리컵 그릇 인간 컵 식사 병 사람 주스병 음식 빵 밥그릇 술병 접시 물컵 텔레비전...

# %%
import random
random.seed(10)
test = random.sample(range(1,100), 10)
test.sort()
test
# Out:
# [2, 5, 27, 36, 55, 60, 62, 63, 74, 84]

# %%
df_detector.loc[test]
# Out:
#     start  end                                             detect
# 2       2    3  그릇 인간 식사 병 주스병 사람 음식 빵 백팩 밥그릇 술병 접시 가방 텔레비전 식탁...
# 5       5    6  유리컵 그릇 인간 컵 식사 키보드 병 운전 주스병 음식 사람 밥그릇 술병 접시 물컵...
# 27     27   28  냉장고 술병 부엌 인간 티비 식사 병 의자 텔레비전 사람 사람들 tv 식탁 병류 주...
# 36     36   37  연 프리스비 원반던지기 테니스 프리즈비 인간 원반 연날리기 의자 사람 사람들 테니스...
# 55     55   56  노트북 일 폰 리모콘 티비 랩탑 작업 컴퓨터 핸드폰 텔레비전 스마트폰 전화 tv 휴...
# 60     60   61  유리컵 그릇 폰 컵 식사 병 주스병 음식 밥그릇 술병 접시 물컵 술잔 와인잔 볼 병...
# 62     62   63  그릇 폰 인간 식사 병 사람 주스병 음식 밥그릇 술병 접시 술잔 와인잔 볼 병류 스...
# 63     63   64  그릇 폰 인간 식사 병 사람 주스병 음식 일 밥그릇 술병 접시 작업 컴퓨터 술잔 와...
# 74     74   75                         화초 리모콘 티비 텔레비전 꽃 화분 tv 리모컨
# 84     84   85                       술병 티비 병 의자 텔레비전 tv 병류 주스병 물병
